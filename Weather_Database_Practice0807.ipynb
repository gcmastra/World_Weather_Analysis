# %%
# GWU Bootcamp Module 6 Web APIs and Pandas Data Frames
# Module 6 Challenge - Deliverable # 1- Retrieve Weather Data and Export to CSV
# Student name: Christopher Mastrangelo

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import random

# very important to include this module - this is what was causing error
import requests

# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Import the API key.  will need to copy the config.py file to this folder
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
# I think -90 to 90 is too likely to pick a non populated area
# Even using -60 to 70 you are going to get some extremely remote locations, most over water 
# start with 20 until its working then scale up to 200 then to 2000 GPS pairs for the challenge

# For the current run - keep cities in USA and Canada including Alaska and Hawaii- just to show I can 
maxsize = 675
lats = np.random.uniform(low=24.000, high=72.000, size=maxsize)
lngs = np.random.uniform(low=-165.000, high=-65.000, size=maxsize)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)
# coordinates

# %%
# This is how we build the unique list of cities. only the name field is unique.  
# question - what if there is a city name like springfield which is located in more than one state?
# that is beyond the scope of this assignment but I would like to verify if the lat/long matches the original used

# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# cities

# I said it before and I will say it again- none of these places are places any traveler would actually go
# they happen to be islands or places along the coast because random pins dropped over the ocean end up in Hawaii
# or Capetown South Africa as the nearest city on the coast
# make sure to add this comment to the README file when submitting the challenge
# Out:
# 257

# %%
# Starting URL for Weather Map API Call - do this outside the loop and do not PRINT IT
# Be careful how many times you run this in case there is a limit on the number of free uses for API Key

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# Create an empty list to hold the weather data.
city_data = []

# for city in cities
for i, city in enumerate(cities):
    
    # Create an endpoint URL for a city.
    city_url = url + "&q=" + city.replace(" ","+")
    
    # copies this code right out of the WeatherPy notebook - we just have to add "description"
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data. Put them in the order we need so we don't have to reorder columns later
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        
        # next line is the new line added
        city_description = city_weather["weather"][0]['description']

        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        if (city_country not in ["CA","US"]):
            print("Skipping ", city.title(), city_country, city_lat, city_lng)
        else:
            city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})
                          # removing date for the challenge was >>> "Date": city_date})
        # show which cities are in Canada, Alaska or Hawaii
        if ((city_lat > 49.75) or (city_lng < -124.6)):
            print(city.title(), city_country, city_lat, city_lng)
            
# If an error is experienced, skip the city. using silent diagnostics instead of print statements 
    except:
        print("City: " + city + " not found. Skipping...")
        pass

# If we process more than 200 cities we should batch them in groups of 50 like the we did in the WeatherPy Notebook
# If we demonstrate using 200 cities in USA and Canada that should prove the code is scalable to 2000 locations
# As indicated above I enhanced random code to only select cities in USA including ALaska Hawaii or Canada
# Out:
# Sioux Lookout CA 50.1001 -91.917
# Moose Factory CA 51.2585 -80.6094
# Kodiak US 57.79 -152.4072
# Yellowknife CA 62.456 -114.3525
# Fort Nelson CA 58.8053 -122.7002
# Ahuimanu US 21.4447 -157.8378
# Skipping  Guadalupe Y Calvo MX 26.1 -106.9667
# Iqaluit CA 63.7506 -68.5145
# Sitka US 57.0531 -135.33
# Skipping  Alexandria EG 31.2156 29.9553
# Kapaa US 22.0752 -159.319
# Skipping  Ojinaga MX 29.5667 -104.4167
# Barrow US 71.2906 -156.7887
# Skipping  Guaymas MX 27.9333 -110.9
# Norman Wells CA 65.282 -126.8329
# College US 64.8569 -147.8028
# Juneau US 58.3019 -134.4197
# Whitehorse CA 60.7161 -135.0538
# Aklavik CA 68.2191 -135.0107
# Skipping  Edinburg GB 55.9521 -3.1965
# Edinburg GB 55.9521 -3.1965
# Port Hardy CA 50.6996 -127.4199
# City: attawapiskat not found. Skipping...
# Kahului US 20.8947 -156.47
# Tuktoyaktuk CA 69.4541 -133.0374
# Hilo US 19.7297 -155.09
# Skipping  Victoria HK 22.2855 114.1577
# Thompson CA 55.7435 -97.8558
# Powell River CA 49.8496 -124.5361
# Skipping  Sidney AU -33.8679 151.2073
# Flin Flon CA 54.7682 -101.865
# Skipping  Newport GB 51.5877 -2.9984
# Newport GB 51.5877 -2.9984
# Smithers CA 54.7804 -127.1743
# La Ronge CA 55.1001 -105.2842
# Kenai US 60.5544 -151.2583
# Terrace CA 54.5163 -128.6035
# High Level CA 58.5169 -117.136
# Lac Du Bonnet CA 50.2536 -96.0612
# Haines Junction CA 60.7522 -137.5108
# Skipping  Cockburn Town TC 21.4612 -71.1419
# Skipping  Rosarito MX 32.3333 -117.0333
# Port-Cartier CA 50.0334 -66.8654
# Clyde River CA 70.4692 -68.5914
# Brooks CA 50.5834 -111.8851
# City: longlac not found. Skipping...
# Kitimat CA 54.0524 -128.6534
# Gimli CA 50.6336 -96.9907
# Nome US 64.5011 -165.4064
# Skipping  San Quintin MX 30.4833 -115.95
# Kailua US 21.4022 -157.7394
# Slave Lake CA 55.2834 -114.769
# Dalmeny CA 52.3334 -106.7679
# Ketchikan US 55.3422 -131.6461
# Skipping  Moctezuma MX 29.8 -109.6667
# Skipping  Steinbach DE 50.1667 8.5667
# Steinbach DE 50.1667 8.5667
# City: grand centre not found. Skipping...
# Lumsden CA 50.6501 -104.8678
# Skipping  Guerrero Negro MX 27.9769 -114.0611
# Homer US 59.6425 -151.5483
# Wahiawa US 21.5028 -158.0236
# Sept-Iles CA 50.2001 -66.3821
# Inuvik CA 68.3499 -133.7218
# Ucluelet CA 48.9329 -125.5528
# Unity CA 52.4501 -109.1682
# Skipping  Mapimi MX 25.8167 -103.85
# Pangnirtung CA 66.1451 -65.7125
# Skipping  Progreso MX 21.2833 -89.6667
# Nanton CA 50.3501 -113.7687
# City: dolbeau not found. Skipping...
# Skipping  Panama City PA 8.9936 -79.5197
# Skipping  Maneadero MX 31.7167 -116.5667
# Hay River CA 60.8156 -115.7999
# Skipping  Marsh Harbour BS 26.5412 -77.0636
# Skipping  Saucillo MX 28.0167 -105.2833
# Skipping  Ocampo MX 21.65 -101.5
# Skipping  Bathurst AU -33.4166 149.5806
# Fairbanks US 64.8378 -147.7164
# Chapais CA 49.7834 -74.8492
# Skipping  Warrington GB 53.3925 -2.5802
# Warrington GB 53.3925 -2.5802
# Skipping  Altar MX 30.7 -111.8167
# City: ahumada not found. Skipping...
# Skipping  Odessa UA 46.4775 30.7326
# Valleyview CA 55.0667 -117.2859
# Rocky Mountain House CA 52.3668 -114.9188
# Skipping  Paris FR 48.8534 2.3488
# Campbell River CA 50.0163 -125.2446
# Skipping  Constitucion CL -35.3333 -72.4167
# Skipping  Abbeville FR 50.1 1.8333
# Abbeville FR 50.1 1.8333
# Kerrobert CA 51.9168 -109.1348
# Skipping  Mocorito MX 25.4833 -107.9167
# Prince Rupert CA 54.3161 -130.3201
# Langham CA 52.3668 -106.9679
# Skipping  Puerto Penasco MX 31.3167 -113.5333
# Skipping  Concordia AR -31.393 -58.0209
# Spirit River CA 55.7833 -118.8361
# Skipping  Caborca MX 30.5838 -111.101
# Skipping  Mulege MX 26.8833 -111.9833
# Mackenzie CA 55.2999 -123.1698
# Wasilla US 61.5814 -149.4394
# Skipping  Abasolo MX 20.45 -101.5167

# %%
# DEBUG - this cell only needs to be run when used to parse the JSON output
# used this cell to traverse the JSON and peel the layers off the onion to get the syntax for each item
# do these steps outside the try/catch so we can see what is going on 

city = 'westminster'
city_url = url + "&q=" + city.replace(" ","+")
        
city_weather = requests.get(city_url).json()
        
# print(city_weather)
# if the status code will not print maybe that is what is causing the catch

city_lat = city_weather["coord"]["lat"]
city_lng = city_weather["coord"]["lon"]
city_max_temp = city_weather["main"]["temp_max"]
city_humidity = city_weather["main"]["humidity"]

# next line is the new line added
city_description = city_weather["weather"][0]['description']

# city_clouds = city_weather["clouds"]["all"]
# city_wind = city_weather["wind"]["speed"]
# city_country = city_weather["sys"]["country"]

    
print(city_description)
city_weather["weather"][0]['description']
# Out:
# haze
# 'haze'

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(20)
# Out:
#                  City Country      Lat       Lng  Max Temp  Humidity  \
# 0       Sioux Lookout      CA  50.1001  -91.9170     57.58        88
# 1   Steamboat Springs      US  40.4850 -106.8317     57.94        78
# 2              Bethel      US  41.3712  -73.4140     80.02        80
# 3              Lompoc      US  34.6391 -120.4579     61.09        92
# 4       Moose Factory      CA  51.2585  -80.6094     53.60        87
# 5              Kodiak      US  57.7900 -152.4072     51.31        87
# 6         Yellowknife      CA  62.4560 -114.3525     64.92        68
# 7           Nantucket      US  41.2835  -70.0995     79.97        89
# 8         Fort Nelson      CA  58.8053 -122.7002     58.59        94
# 9            Ahuimanu      US  21.4447 -157.8378     77.94        75
# 10            Iqaluit      CA  63.7506  -68.5145     46.13        81
# 11           Havelock      US  34.8791  -76.9013     82.38        87
# 12              Sitka      US  57.0531 -135.3300     58.89        88
# 13            Fortuna      US  40.5982 -124.1573     59.09        75
# 14           Redlands      US  34.0556 -117.1825     84.15        55
# 15         North Bend      US  43.4065 -124.2243     62.94       100
# 16             Malibu      US  34.0050 -118.8101     67.55        92
# 17              Kapaa      US  22.0752 -159.3190     79.12        75
# 18       Mastic Beach      US  40.7668  -72.8521     81.99        75
# 19             Barrow      US  71.2906 -156.7887     35.62        82
#
#     Cloudiness  Wind Speed Current Description
# 0           75        5.75               smoke
# 1           75        0.00                haze
# 2          100        6.87     overcast clouds
# 3           90        3.44                mist
# 4            1        4.61           clear sky
# 5           75        3.44       broken clouds
# 6           75       13.80               smoke
# 7            1        9.22           clear sky
# 8           90        9.22       moderate rain
# 9           25       16.20    scattered clouds
# 10          90       14.97          light rain
# 11          75        3.00       broken clouds
# 12          90        4.61          light rain
# 13          90        3.44     overcast clouds
# 14           0        0.22           clear sky
# 15          84        0.00                 fog
# 16          76        1.01       broken clouds
# 17          20        1.01          light rain
# 18           1        1.01           clear sky
# 19          90        3.44     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "./WeatherPy_Database.csv"
# Export the City_Data into a CSV. SAme folder that we are in which should be World_Weather

# ONLY RE-ENABLE THIS LIINE IF YOU WANT TO SAVE ANOTHER COPY OF THE OUTPUT FILE 
# Header default is TRUE so no need to include the column headers except the label for the first column
# city_data_df.to_csv(output_data_file, index_label="City_ID")

# Looks like we are ready to submit Deliverable #1 for Module 6 Challenge date 2021-08-06

# %%
# Sat 8-7 Practice - before I work on the heatmaps I want to create a map of just the lat/longs of the cities above
# just to see the locations of the city on the map and compare it to the lat/long pairs used to generate the cities

# still need to install gmaps in the back end using anaconda prompt- this might be a good office hours question
# it was still waiting for a y/n answer so it had not installed yet

import gmaps
import gmaps.datasets

# Import the API key.
from config import g_key

# Configure gmaps to use your Google API key.
gmaps.configure(api_key=g_key)

# Heatmap of percent humidity
locations = city_data_df[["Lat", "Lng"]]
humidity = city_data_df["Humidity"]

fig = gmaps.figure(center=(40.0, -75.0), zoom_level=8)

# marker_layer labels work but they are hard to read at same size/font as the background map 
marker_layer = gmaps.marker_layer(locations, label=city_data_df["City"])
fig.add_layer(marker_layer)

# use symbols vs markers to show the original set of lat/long points used to generate the citis 
# the list used to xxx was called coordinates not cities
symbol_layer = gmaps.symbol_layer(coordinates, scale=5)
fig.add_layer(symbol_layer)


# directions later - can you really do this?? yes but then you can't save the map 
start = (42.35, -71.112)
end = (38.8, -77.223)
waypoints = [(40.01, -75.01)]
directions = gmaps.directions_layer(start, end, waypoints=waypoints)
# fig.add_layer(directions)

# fig.add_layer(heat_layer)

# Call the figure to plot the data.
# fig

# %%
# get these using a input statement but first I will enter them to test the df below
# min_temp = 65.03
# max_temp = 88.98

# Ask the customer to add a minimum and maximum temperature value.
min_temp = float(input("What is the minimum temperature you would like for your trip? "))
max_temp = float(input("What is the maximum temperature you would like for your trip? "))

# Filter the dataset to find the cities that fit the criteria.
preferred_cities_df = city_data_df.loc[(city_data_df["Max Temp"] <= max_temp) & \
                                       (city_data_df["Max Temp"] >= min_temp)]
preferred_cities_df
# Out:
# What is the minimum temperature you would like for your trip? 77.9358
# What is the maximum temperature you would like for your trip? 99.555
#                 City Country      Lat       Lng  Max Temp  Humidity  \
# 2             Bethel      US  41.3712  -73.4140     80.02        80
# 7          Nantucket      US  41.2835  -70.0995     79.97        89
# 9           Ahuimanu      US  21.4447 -157.8378     77.94        75
# 11          Havelock      US  34.8791  -76.9013     82.38        87
# 14          Redlands      US  34.0556 -117.1825     84.15        55
# ..               ...     ...      ...       ...       ...       ...
# 211       San Angelo      US  31.4638 -100.4370     79.54        80
# 212         Key West      US  24.5557  -81.7826     89.60        64
# 213       Alamogordo      US  32.8995 -105.9603     79.95        45
# 215        Fairfield      US  41.2668  -73.3162     80.65        78
# 216  New Port Richey      US  28.2442  -82.7193     87.98        80
#
#      Cloudiness  Wind Speed Current Description
# 2           100        6.87     overcast clouds
# 7             1        9.22           clear sky
# 9            25       16.20    scattered clouds
# 11           75        3.00       broken clouds
# 14            0        0.22           clear sky
# ..          ...         ...                 ...
# 211          75        1.99       broken clouds
# 212          20       12.66          few clouds
# 213           1        6.91           clear sky
# 215         100        7.14     overcast clouds
# 216           8        1.99           clear sky
#
# [65 rows x 9 columns]

# %%
preferred_cities_df.count()
# Out:
# City                   65
# Country                65
# Lat                    65
# Lng                    65
# Max Temp               65
# Humidity               65
# Cloudiness             65
# Wind Speed             65
# Current Description    65
# dtype: int64

# %%
# Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.
hotel_df = preferred_cities_df[["City", "Country", "Max Temp", "Lat", "Lng"]].copy()
hotel_df["Hotel Name"] = ""
hotel_df.head(10)
# Out:
#             City Country  Max Temp      Lat       Lng Hotel Name
# 2         Bethel      US     80.02  41.3712  -73.4140
# 7      Nantucket      US     79.97  41.2835  -70.0995
# 9       Ahuimanu      US     77.94  21.4447 -157.8378
# 11      Havelock      US     82.38  34.8791  -76.9013
# 14      Redlands      US     84.15  34.0556 -117.1825
# 17         Kapaa      US     79.12  22.0752 -159.3190
# 18  Mastic Beach      US     81.99  40.7668  -72.8521
# 22          Mayo      US     79.99  38.8876  -76.5119
# 29    Beamsville      CA     80.89  43.1668  -79.4829
# 30      Hamilton      US     78.89  39.1834  -84.5333

# %%
# section 6.5.4 find hotels around a location using API lookup 
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
# we will build the params including the API Key
params = "&key=" + g_key + "&q="
# params
# use my home GPS coords as test of the code before adding it to loop
plat = 38.801
plng = -77.223
pref_city = f"{plat},{plng}"
# Set parameters to search for a hotel.
params = {
    "radius": 5000,
    "type": "lodging",
    "key": g_key,
    "location": pref_city
}

# Make request and get the JSON data from the search.
hotels = requests.get(base_url, params=params).json()

hotels
# Out:
# {'html_attributions': [],
#  'results': [{'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 38.78022000000001, 'lng': -77.18251},
#     'viewport': {'northeast': {'lat': 38.78159058029151,
#       'lng': -77.18135941970849},
#      'southwest': {'lat': 38.77889261970851, 'lng': -77.1840573802915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Holiday Inn Express Washington DC SW - Springfield, an IHG Hotel',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 533,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/103652742749938049887">Holiday Inn Express Washington DC SW - Springfield, an IHG Hotel</a>'],
#      'photo_reference': 'Aap_uEDdNi4m0cqGQ4fxT9w0mMXbBSg-7xnDtFy06KmyY3CihZVHdwXAdDGy4GuokEyMGmFCGZt3uY8boQs91dto-bl8DeF4qlUSfB6Bl7V-KnUMxszaNqXWTq0pxlYLnQiMAClMSpQbVluwzDjUeYyiS5DSJCguJTT-pcendsqP2g_7SIs',
#      'width': 800}],
#    'place_id': 'ChIJQ1xc3Keyt4kRwq0UkVXIm-w',
#    'plus_code': {'compound_code': 'QRJ8+3X Springfield, VA, USA',
#     'global_code': '87C4QRJ8+3X'},
#    'rating': 4.2,
#    'reference': 'ChIJQ1xc3Keyt4kRwq0UkVXIm-w',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 734,
#    'vicinity': '6401 Brandon Avenue, Springfield'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 38.7807327, 'lng': -77.1765556},
#     'viewport': {'northeast': {'lat': 38.78189778029149,
#       'lng': -77.17541691970851},
#      'southwest': {'lat': 38.7791998197085, 'lng': -77.17811488029152}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Courtyard by Marriott Springfield',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 810,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/109186315471177959366">Courtyard by Marriott Springfield</a>'],
#      'photo_reference': 'Aap_uED4Eo5Poba3eymL_SINcpIhj7kW3kj0E6Gb7Cy7uechkh1_0QWM6cOlWYehWdMVvBsStswOwAtrGUmBuxr6NaTPXIDG__cbeq7Mu1U10WuQgV9Dlq9ybNfutL_tG7cuxmTF0oPAht5HS6zw33fTM9tInjw9zmjB8KsCnSfk8jok9GxJ',
#      'width': 1440}],
#    'place_id': 'ChIJT98qK6eyt4kRnT02I7smv7s',
#    'plus_code': {'compound_code': 'QRJF+79 Springfield, VA, USA',
#     'global_code': '87C4QRJF+79'},
#    'rating': 4,
#    'reference': 'ChIJT98qK6eyt4kRnT02I7smv7s',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 634,
#    'vicinity': '6710 Commerce Street, Springfield'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 38.77969559999999, 'lng': -77.1864552},
#     'viewport': {'northeast': {'lat': 38.78088218029151,
#       'lng': -77.1851130197085},
#      'southwest': {'lat': 38.77818421970851, 'lng': -77.1878109802915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Homewood Suites by Hilton Springfield, VA',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1551,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/105357328668754991466">Homewood Suites by Hilton Springfield, VA</a>'],
#      'photo_reference': 'Aap_uEC8_VWzheExFTY0SF3_JZWJ6F-avSpDXC1jfxjgKxzPZiT_grtWS1wS3pOMqNK0vdxATV7ufgx3RlkMGnUn3asouGblFR-s2mrePNSBGwReeibRs0pCT1FQlUTMNWjxaZVrp00EO7x_e2yzzwWY7E6Rlam68dy5N5eXGh9zrelbsREv',
#      'width': 2048}],
#    'place_id': 'ChIJ3eL2z6myt4kRLni8cZt_6L4',
#    'plus_code': {'compound_code': 'QRH7+VC Springfield, VA, USA',
#     'global_code': '87C4QRH7+VC'},
#    'rating': 4.3,
#    'reference': 'ChIJ3eL2z6myt4kRLni8cZt_6L4',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 632,
#    'vicinity': '7010 Old Keene Mill Road, Springfield'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 38.7771457, 'lng': -77.1777111},
#     'viewport': {'northeast': {'lat': 38.7784475302915,
#       'lng': -77.17621096970849},
#      'southwest': {'lat': 38.7757495697085, 'lng': -77.1789089302915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Hilton Springfield',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1969,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/112825361459310700552">Hilton Springfield</a>'],
#      'photo_reference': 'Aap_uEAUADMhs0mQ-6rkEE_To6rOPPHk-pjKszbKwuDgndtpM3Ku7XKrVljOYlnjC_IBIKiPGC5XUtdB1zhGWz3dz_Ebj2fyszjwnzPu3-8GnFvFrnM_MoW0i78M6WQw66RVLativCsAL8CiKrhRWSrsa01vCAoSdWOtTxNx4hPvtCW0GPWN',
#      'width': 2048}],
#    'place_id': 'ChIJlf90sVitt4kRgQFmsB1cBHg',
#    'plus_code': {'compound_code': 'QRGC+VW Springfield, VA, USA',
#     'global_code': '87C4QRGC+VW'},
#    'rating': 4.1,
#    'reference': 'ChIJlf90sVitt4kRgQFmsB1cBHg',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 1123,
#    'vicinity': '6550 Loisdale Road, Springfield'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 38.7795765, 'lng': -77.1851295},
#     'viewport': {'northeast': {'lat': 38.7811127802915,
#       'lng': -77.18391266970849},
#      'southwest': {'lat': 38.7784148197085, 'lng': -77.1866106302915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Residence Inn by Marriott Springfield Old Keene Mill',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 4032,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/101103185032176118301">Mike McILwain</a>'],
#      'photo_reference': 'Aap_uEBo4xZtwfinwRT3_5YGKD42iKSKhSDrVcv-L61J6FZihAFUmNyeuJWbzRC1weTbYTpw-WocdG38stkZ6zTruMezjwBqs9KccRvHjlGoPvD4m0vcT7T_BOis5B3F3-rUthyCpGppG0vrDGGbphsB1Px5mmh96jxS9oopFuApMDK4Dj0q',
#      'width': 3024}],
#    'place_id': 'ChIJg9dyOqiyt4kRlLLbcFbXlM0',
#    'plus_code': {'compound_code': 'QRH7+RW Springfield, VA, USA',
#     'global_code': '87C4QRH7+RW'},
#    'rating': 4.4,
#    'reference': 'ChIJg9dyOqiyt4kRlLLbcFbXlM0',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 482,
#    'vicinity': '6412 Backlick Road, Springfield'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 38.78252670000001,
#      'lng': -77.18171099999999},
#     'viewport': {'northeast': {'lat': 38.7839526802915,
#       'lng': -77.1802174697085},
#      'southwest': {'lat': 38.78125471970851, 'lng': -77.1829154302915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'TownePlace Suites by Marriott Springfield',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1366,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/116204172159929823025">TownePlace Suites by Marriott Springfield</a>'],
#      'photo_reference': 'Aap_uECEaaT84FUZPqX2csqSujoOrO-m4SJgzZe_8BSXFnS5DoWy47lUaP7Kh4jpyXj73e7Vqi_EE1IlFFwY8IUpyOssTw6-UlWUJdMdch5OgxET3SPBEIrXY5zjQa7fcy_6KRa0oEYoTO_GVWk1xjcT8lmCcDXaL_m3HY5mx8Oq76dKnK6l',
#      'width': 2048}],
#    'place_id': 'ChIJObIoPqayt4kRnuaKGYxgd70',
#    'plus_code': {'compound_code': 'QRM9+28 Springfield, VA, USA',
#     'global_code': '87C4QRM9+28'},
#    'rating': 3.9,
#    'reference': 'ChIJObIoPqayt4kRnuaKGYxgd70',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 344,
#    'vicinity': '6245 Brandon Avenue, Springfield'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 38.777219, 'lng': -77.183037},
#     'viewport': {'northeast': {'lat': 38.7785215802915,
#       'lng': -77.18157736970849},
#      'southwest': {'lat': 38.7758236197085, 'lng': -77.1842753302915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Motel 6 Springfield, VA - Washington DC Southwest',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 325,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/112255657241482613159">Motel 6 Springfield, VA - Washington DC Southwest</a>'],
#      'photo_reference': 'Aap_uEB0yAGK9QpV_CGDc-bXBY98rB-WrNB9aB3f5hDhRY27LOi4VMIW0khgyAlSUPT5RTBbD1ROZZPh8nhjl7hTBvCaxFpI9qEIDX7ZQba1m6dCdtF8kg9FmQttSjrITTWZeaWRejSRno5585iF28cvVZsQFtQ8bHXf7lir7_aYqKGoif9b',
#      'width': 500}],
#    'place_id': 'ChIJuRH3IFitt4kR-zvMRh4cMzY',
#    'plus_code': {'compound_code': 'QRG8+VQ Springfield, VA, USA',
#     'global_code': '87C4QRG8+VQ'},
#    'rating': 3.6,
#    'reference': 'ChIJuRH3IFitt4kR-zvMRh4cMzY',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 939,
#    'vicinity': '6868 Springfield Boulevard, Springfield'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 38.7802623, 'lng': -77.17836609999999},
#     'viewport': {'northeast': {'lat': 38.7816739802915,
#       'lng': -77.17662056970849},
#      'southwest': {'lat': 38.7789760197085, 'lng': -77.1793185302915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Best Western Springfield',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2160,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107028794723430378935">Best Western Springfield</a>'],
#      'photo_reference': 'Aap_uEAre-g0i56Xz5cM3fCf_G4i7BAKOE-qlEjMLxuCLaHV3AjKRzs6NDnb5ub0RWaoUFDNRayNGBC43NxsUQLo4USsDyfANOoLClmmNf3PtN7AUdRNiM9a5RSG7-Oj8-pxsAoar6tBg27K7rEnYxzhXWmGZfg8YciYTlcQ5Z3IvqjsjYLP',
#      'width': 3840}],
#    'place_id': 'ChIJUSYiJKeyt4kRTN6ey3nE8T8',
#    'plus_code': {'compound_code': 'QRJC+4M Springfield, VA, USA',
#     'global_code': '87C4QRJC+4M'},
#    'rating': 3.4,
#    'reference': 'ChIJUSYiJKeyt4kRTN6ey3nE8T8',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 901,
#    'vicinity': '6721 Commerce Street, Springfield'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 38.77624759999999, 'lng': -77.1788466},
#     'viewport': {'northeast': {'lat': 38.7776067802915,
#       'lng': -77.1774312197085},
#      'southwest': {'lat': 38.77490881970851, 'lng': -77.1801291802915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Comfort Inn',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2988,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/116112897700372922602">Jerri Peterson</a>'],
#      'photo_reference': 'Aap_uEBaq78G_E4SMOVqKr1nU7bfboMW6rujea7IVFnXavAN8dLQfVwWIN_92YA9mMMraHm_dOh4jRcRiKswky8oeQk_3eIWM-FPRqrNOhtvDb1bZk-DVH3TV_w1E7YqDM96UEl1OAwGA2puePhStgdIcRxv2bP2ZAyHHgkFrVEHDDn74Egw',
#      'width': 5312}],
#    'place_id': 'ChIJj8wj6litt4kRNYdWUf12yf4',
#    'plus_code': {'compound_code': 'QRGC+FF Springfield, VA, USA',
#     'global_code': '87C4QRGC+FF'},
#    'rating': 3.8,
#    'reference': 'ChIJj8wj6litt4kRNYdWUf12yf4',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 709,
#    'vicinity': '6560 Loisdale Court, Springfield'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 38.7771044, 'lng': -77.178936},
#     'viewport': {'northeast': {'lat': 38.7784261802915,
#       'lng': -77.1774701697085},
#      'southwest': {'lat': 38.7757282197085, 'lng': -77.1801681302915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Wingate by Wyndham Springfield',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 400,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/101445363140580046674">Wingate by Wyndham Springfield</a>'],
#      'photo_reference': 'Aap_uEC7dgHVdpPTsp2YuCuTBB3YzMwv0dukgAgJzg8eeuFTxs6J46CxGF4pxGAsNPsU4chWM0fnGbd0IOY9EUIhU10NxeEjVU7WrIgwPQNkbEpemFTpShDUOca2MW3ImgQUpWKbCHy-H_vnvVoNVw-YyxqtvXcMBkITW_dGDTCoX8cjkXmS',
#      'width': 599}],
#    'place_id': 'ChIJR8L5lFitt4kRQTuPmyfUcPw',
#    'plus_code': {'compound_code': 'QRGC+RC Springfield, VA, USA',
#     'global_code': '87C4QRGC+RC'},
#    'rating': 3.8,
#    'reference': 'ChIJR8L5lFitt4kRQTuPmyfUcPw',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 833,
#    'vicinity': '6550 Loisdale Court, Springfield'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 38.8176432, 'lng': -77.21052739999999},
#     'viewport': {'northeast': {'lat': 38.8190211302915,
#       'lng': -77.20928231970849},
#      'southwest': {'lat': 38.8163231697085, 'lng': -77.21198028029151}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Diana’s closet',
#    'place_id': 'ChIJmz9caHJNtokRQOQeKnZVKHk',
#    'plus_code': {'compound_code': 'RQ9Q+3Q Annandale, VA, USA',
#     'global_code': '87C4RQ9Q+3Q'},
#    'rating': 4,
#    'reference': 'ChIJmz9caHJNtokRQOQeKnZVKHk',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 2,
#    'vicinity': '4917 Heritage Court, Annandale'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 38.8192534, 'lng': -77.209493},
#     'viewport': {'northeast': {'lat': 38.82052883029152,
#       'lng': -77.20813286970849},
#      'southwest': {'lat': 38.81783086970852, 'lng': -77.2108308302915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': "Ross' Closet",
#    'place_id': 'ChIJN6kZXrxNtokR8Bb8iePLGqw',
#    'plus_code': {'compound_code': 'RQ9R+P6 Annandale, VA, USA',
#     'global_code': '87C4RQ9R+P6'},
#    'reference': 'ChIJN6kZXrxNtokR8Bb8iePLGqw',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'vicinity': '7614 Newcastle Drive, Annandale'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 38.8275, 'lng': -77.21809689999999},
#     'viewport': {'northeast': {'lat': 38.82884628029149,
#       'lng': -77.21674001970848},
#      'southwest': {'lat': 38.82614831970849, 'lng': -77.2194379802915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Heritage Court Condominium',
#    'photos': [{'height': 1280,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/108593078645204346452">Martin Villarroel</a>'],
#      'photo_reference': 'Aap_uECEwj-MsIRDNNFK8XSSplMoy4XxhQjevZK_64Tf5WdPfrBuEeagP-nu0kTWWtnh5FQGmgvZ-JQ_hvp_PlWlzqsOyP_5OfgLY9r_osSSRhydZp8R56fDZgf8KEUIM3EuVInJ7KUISt-EvV5Mt33cu1fumKnM2ZbxQgYPEeZb-jOCampr',
#      'width': 720}],
#    'place_id': 'ChIJbR4LazpNtokR1uDwRs37c_o',
#    'plus_code': {'compound_code': 'RQGJ+XQ Annandale, VA, USA',
#     'global_code': '87C4RQGJ+XQ'},
#    'rating': 1.5,
#    'reference': 'ChIJbR4LazpNtokR1uDwRs37c_o',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 6,
#    'vicinity': '4499-4401 Island Place, Annandale'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 38.83190809999999,
#      'lng': -77.20763099999999},
#     'viewport': {'northeast': {'lat': 38.8333746802915,
#       'lng': -77.20630231970848},
#      'southwest': {'lat': 38.8306767197085, 'lng': -77.20900028029149}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Women tea party scalpture',
#    'photos': [{'height': 3024,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/114296653443227803873">Mohd Hossein Yarmohammadian</a>'],
#      'photo_reference': 'Aap_uEBMRx967Gz48r5zBcTGzwX0dMFswHTbIO-Z_PkGoS4ja8aNYloJZkpLIWrTtYS-egl4NhxdZqq3OxyVHDS1ien3o_NoGUBLoYE0Ni8gKNSGCNFCB69FeoFoGIZDejQp3TlNTUX3uMg1ZikCLM-a89gdgFYeOhRxtTQHps6Kui3vgyvM',
#      'width': 4032}],
#    'place_id': 'ChIJwY_MC9NNtokR_gHPmbF4yBI',
#    'plus_code': {'compound_code': 'RQJR+QW Annandale, VA, USA',
#     'global_code': '87C4RQJR+QW'},
#    'rating': 5,
#    'reference': 'ChIJwY_MC9NNtokR_gHPmbF4yBI',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 1,
#    'vicinity': '7601 Little River Turnpike, Annandale'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 38.7802189, 'lng': -77.1827011},
#     'viewport': {'northeast': {'lat': 38.7815477302915,
#       'lng': -77.18146181970849},
#      'southwest': {'lat': 38.7788497697085, 'lng': -77.1841597802915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Holiday Inn Hotel',
#    'place_id': 'ChIJe4W5gqWyt4kRM44P8BuqbDU',
#    'plus_code': {'compound_code': 'QRJ8+3W Springfield, VA, USA',
#     'global_code': '87C4QRJ8+3W'},
#    'rating': 4.1,
#    'reference': 'ChIJe4W5gqWyt4kRM44P8BuqbDU',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 7,
#    'vicinity': '6007-6099 Brandon Avenue, Springfield'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 38.8351816, 'lng': -77.1996037},
#     'viewport': {'northeast': {'lat': 38.83652373029149,
#       'lng': -77.1982373697085},
#      'southwest': {'lat': 38.8338257697085, 'lng': -77.20093533029151}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Apartment Building',
#    'place_id': 'ChIJg8cZX6lNtokR2L3pcVd_Svk',
#    'plus_code': {'compound_code': 'RRP2+35 Annandale, VA, USA',
#     'global_code': '87C4RRP2+35'},
#    'reference': 'ChIJg8cZX6lNtokR2L3pcVd_Svk',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'vicinity': '4202 Whitney Street, Annandale'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 38.8058945, 'lng': -77.17070729999999},
#     'viewport': {'northeast': {'lat': 38.8072917802915,
#       'lng': -77.16930791970849},
#      'southwest': {'lat': 38.8045938197085, 'lng': -77.1720058802915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'No turn around for Tractor Trailers',
#    'place_id': 'ChIJeaAY2xezt4kRC8idwODj-uU',
#    'plus_code': {'compound_code': 'RR4H+9P Springfield, VA, USA',
#     'global_code': '87C4RR4H+9P'},
#    'reference': 'ChIJeaAY2xezt4kRC8idwODj-uU',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'vicinity': '6559 Edsall Road, Springfield'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 38.7765426, 'lng': -77.178842},
#     'viewport': {'northeast': {'lat': 38.7777644302915,
#       'lng': -77.1774290197085},
#      'southwest': {'lat': 38.7750664697085, 'lng': -77.1801269802915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'hotel',
#    'place_id': 'ChIJTdpgoX2tt4kRt8ivyne1enE',
#    'plus_code': {'compound_code': 'QRGC+JF Springfield, VA, USA',
#     'global_code': '87C4QRGC+JF'},
#    'reference': 'ChIJTdpgoX2tt4kRt8ivyne1enE',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'vicinity': '6560 Loisdale Court, Springfield'}],
#  'status': 'OK'}

# %%
# peel the onion
num_hotels = len(hotels['results'])
first_hotel = hotels['results'][0]['name']
first_hotel
# Out:
# 'Holiday Inn Express Washington DC SW - Springfield, an IHG Hotel'

# %%
# Iterate through the DataFrame.
for index, row in hotel_df.iterrows():
    # Get the latitude and longitude.
    lat = row["Lat"]
    lng = row["Lng"]

    # Add the latitude and longitude to location key for the params dictionary.
    params["location"] = f"{lat},{lng}"
    
    try:
        # Use the search term: "lodging" and our latitude and longitude.
        base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
        # Make request and get the JSON data from the search.
        hotels = requests.get(base_url, params=params).json()
        # Grab the first hotel from the results and store the name.
        hotel_df.loc[index, "Hotel Name"] = hotels["results"][0]["name"]
    except (IndexError):
        city_name = row["City"]        
        print("Hotel not found for city = " + city_name + " not found... skipping.")
# Out:
# Hotel not found for city = Bristol not found... skipping.
# Hotel not found for city = Merritt Island not found... skipping.
# Hotel not found for city = Fairfield not found... skipping.

# %%
# check for any nulls in the hotel name before moving forward three cities should have a null? no it says they are all there
hotel_df.count()
# Out:
# City          65
# Country       65
# Max Temp      65
# Lat           65
# Lng           65
# Hotel Name    65
# dtype: int64

# %%
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""

# Store the DataFrame Row.
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
len(hotel_info)
# Out:
# 65

# %%
# Add a heatmap of temperature for the vacation spots and marker for each city.
locations = hotel_df[["Lat", "Lng"]]
max_temp = hotel_df["Max Temp"]
fig = gmaps.figure(center=(40.0, -75.0), zoom_level=6)

heat_layer = gmaps.heatmap_layer(locations, weights=max_temp,
             dissipating=False, max_intensity=300, point_radius=4)

marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)

# fig.add_layer(heat_layer)
fig.add_layer(marker_layer)
# Call the figure to plot the data. Do it in the next cell to test for errors first without building map every time
# fig

# it works but the way they use heat maps in this lesson does not tell you anything of value
# a hot area on the map just means there are more hotels or pins in that area, not the actual temperature

# %%
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
